# %%
pices_a = [8.70,8.91,8.71]

# %%
import numpy as np

# %%
pices_a = np.array(pices_a)

# %%
pices_a[1:]/pices_a[:-1] -1
# Out:
# array([ 0.02413793, -0.02244669])

# %%
import pandas as pd

# %%
prices = pd.read_csv("data/sample_prices.csv")

# %%
returns = prices.pct_change()

# %%
prices.plot()

# %%
returns.plot.bar()

# %%
returns.std()
# Out:
# BLUE      0.023977
# ORANGE    0.079601
# dtype: float64

# %%
(returns+1).prod() -1
# Out:
# BLUE      0.123310
# ORANGE    0.087167
# dtype: float64
